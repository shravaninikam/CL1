# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('Real_estate.csv')

# %%
data.head()
# Out:
#    No  X1 transaction date  X2 house age  \
# 0   1             2012.917          32.0
# 1   2             2012.917          19.5
# 2   3             2013.583          13.3
# 3   4             2013.500          13.3
# 4   5             2012.833           5.0
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                84.87882                               10
# 1                               306.59470                                9
# 2                               561.98450                                5
# 3                               561.98450                                5
# 4                               390.56840                                5
#
#    X5 latitude  X6 longitude  Y house price of unit area
# 0     24.98298     121.54024                        37.9
# 1     24.98034     121.53951                        42.2
# 2     24.98746     121.54391                        47.3
# 3     24.98746     121.54391                        54.8
# 4     24.97937     121.54245                        43.1

# %%
columns = list(data.columns)
columns
# Out:
# ['No',
#  'X1 transaction date',
#  'X2 house age',
#  'X3 distance to the nearest MRT station',
#  'X4 number of convenience stores',
#  'X5 latitude',
#  'X6 longitude',
#  'Y house price of unit area']

# %%
columns = [col.replace(' ','_') for col in columns]
columns
# Out:
# ['No',
#  'X1_transaction_date',
#  'X2_house_age',
#  'X3_distance_to_the_nearest_MRT_station',
#  'X4_number_of_convenience_stores',
#  'X5_latitude',
#  'X6_longitude',
#  'Y_house_price_of_unit_area']

# %%
data.columns = columns
data.head()
# Out:
#    No  X1_transaction_date  X2_house_age  \
# 0   1             2012.917          32.0
# 1   2             2012.917          19.5
# 2   3             2013.583          13.3
# 3   4             2013.500          13.3
# 4   5             2012.833           5.0
#
#    X3_distance_to_the_nearest_MRT_station  X4_number_of_convenience_stores  \
# 0                                84.87882                               10
# 1                               306.59470                                9
# 2                               561.98450                                5
# 3                               561.98450                                5
# 4                               390.56840                                5
#
#    X5_latitude  X6_longitude  Y_house_price_of_unit_area
# 0     24.98298     121.54024                        37.9
# 1     24.98034     121.53951                        42.2
# 2     24.98746     121.54391                        47.3
# 3     24.98746     121.54391                        54.8
# 4     24.97937     121.54245                        43.1

# %%
start_date = 2012.917
end_date = 2015.813

# %%
filtered_data = data[(data['X1_transaction_date'] >= start_date) & (data['X1_transaction_date'] <= end_date)]
filtered_data
# Out:
#       No  X1_transaction_date  X2_house_age  \
# 0      1             2012.917          32.0
# 1      2             2012.917          19.5
# 2      3             2013.583          13.3
# 3      4             2013.500          13.3
# 7      8             2013.417          20.3
# ..   ...                  ...           ...
# 408  409             2013.417          18.5
# 409  410             2013.000          13.7
# 411  412             2013.250          18.8
# 412  413             2013.000           8.1
# 413  414             2013.500           6.5
#
#      X3_distance_to_the_nearest_MRT_station  X4_number_of_convenience_stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# 7                                 287.60250                                6
# ..                                      ...                              ...
# 408                              2175.74400                                3
# 409                              4082.01500                                0
# 411                               390.96960                                7
# 412                               104.81010                                5
# 413                                90.45606                                9
#
#      X5_latitude  X6_longitude  Y_house_price_of_unit_area
# 0       24.98298     121.54024                        37.9
# 1       24.98034     121.53951                        42.2
# 2       24.98746     121.54391                        47.3
# 3       24.98746     121.54391                        54.8
# 7       24.98042     121.54228                        46.7
# ..           ...           ...                         ...
# 408     24.96330     121.51243                        28.1
# 409     24.94155     121.50381                        15.4
# 411     24.97923     121.53986                        40.6
# 412     24.96674     121.54067                        52.5
# 413     24.97433     121.54310                        63.9
#
# [326 rows x 8 columns]

# %%
house_age = 20
filtered_data = data[data['X2_house_age'] > house_age]
filtered_data
# Out:
#       No  X1_transaction_date  X2_house_age  \
# 0      1             2012.917          32.0
# 6      7             2012.667          34.5
# 7      8             2013.417          20.3
# 8      9             2013.500          31.7
# 10    11             2013.083          34.8
# ..   ...                  ...           ...
# 395  396             2012.917          21.2
# 396  397             2012.667          37.1
# 400  401             2013.250          26.8
# 403  404             2012.667          30.9
# 405  406             2012.667          23.0
#
#      X3_distance_to_the_nearest_MRT_station  X4_number_of_convenience_stores  \
# 0                                  84.87882                               10
# 6                                 623.47310                                7
# 7                                 287.60250                                6
# 8                                5512.03800                                1
# 10                                405.21340                                1
# ..                                      ...                              ...
# 395                               512.54870                                4
# 396                               918.63570                                1
# 400                               482.75810                                5
# 403                               161.94200                                9
# 405                               130.99450                                6
#
#      X5_latitude  X6_longitude  Y_house_price_of_unit_area
# 0       24.98298     121.54024                        37.9
# 6       24.97933     121.53642                        40.3
# 7       24.98042     121.54228                        46.7
# 8       24.95095     121.48458                        18.8
# 10      24.97349     121.53372                        41.4
# ..           ...           ...                         ...
# 395     24.97400     121.53842                        42.5
# 396     24.97198     121.55063                        31.9
# 400     24.97433     121.53863                        35.5
# 403     24.98353     121.53966                        39.7
# 405     24.95663     121.53765                        37.2
#
# [137 rows x 8 columns]

# %%
data_sorted_age = data.sort_values(by='X2_house_age')
data_sorted_age
# Out:
#       No  X1_transaction_date  X2_house_age  \
# 166  167             2013.417           0.0
# 103  104             2012.750           0.0
# 373  374             2013.083           0.0
# 105  106             2012.833           0.0
# 123  124             2013.417           0.0
# ..   ...                  ...           ...
# 128  129             2013.083          41.3
# 173  174             2013.083          41.3
# 361  362             2013.083          41.4
# 392  393             2013.083          42.7
# 192  193             2013.167          43.8
#
#      X3_distance_to_the_nearest_MRT_station  X4_number_of_convenience_stores  \
# 166                               292.99780                                6
# 103                               208.39050                                6
# 373                               274.01440                                1
# 105                               292.99780                                6
# 123                               185.42960                                0
# ..                                      ...                              ...
# 128                               124.99120                                6
# 173                               401.88070                                4
# 361                               281.20500                                8
# 392                               443.80200                                6
# 192                                57.58945                                7
#
#      X5_latitude  X6_longitude  Y_house_price_of_unit_area
# 166     24.97744     121.54458                        73.6
# 103     24.95618     121.53844                        45.7
# 373     24.97480     121.53059                        52.2
# 105     24.97744     121.54458                        71.0
# 123     24.97110     121.53170                        45.5
# ..           ...           ...                         ...
# 128     24.96674     121.54039                        60.7
# 173     24.98326     121.54460                        35.1
# 361     24.97345     121.54093                        63.3
# 392     24.97927     121.53874                        35.3
# 192     24.96750     121.54069                        42.7
#
# [414 rows x 8 columns]

# %%
def assign_group(row):
    if row['X2_house_age'] <= 10:
        return 'Group 1'
    elif row['X2_house_age'] <= 20:
        return 'Group 2'
    else:
        return 'Group 3'
    
data['group'] = data.apply(assign_group, axis=1)
data.head()
# Out:
#    No  X1_transaction_date  X2_house_age  \
# 0   1             2012.917          32.0
# 1   2             2012.917          19.5
# 2   3             2013.583          13.3
# 3   4             2013.500          13.3
# 4   5             2012.833           5.0
#
#    X3_distance_to_the_nearest_MRT_station  X4_number_of_convenience_stores  \
# 0                                84.87882                               10
# 1                               306.59470                                9
# 2                               561.98450                                5
# 3                               561.98450                                5
# 4                               390.56840                                5
#
#    X5_latitude  X6_longitude  Y_house_price_of_unit_area    group
# 0     24.98298     121.54024                        37.9  Group 3
# 1     24.98034     121.53951                        42.2  Group 2
# 2     24.98746     121.54391                        47.3  Group 2
# 3     24.98746     121.54391                        54.8  Group 2
# 4     24.97937     121.54245                        43.1  Group 1

# %%
average_price_by_group = data.groupby('group')['Y_house_price_of_unit_area'].mean()
print(average_price_by_group)
# Out:
# group
# Group 1    46.608182
# Group 2    34.138323
# Group 3    35.735766
# Name: Y_house_price_of_unit_area, dtype: float64

# %%
q1 = np.percentile(data['Y_house_price_of_unit_area'], 25)
q3 = np.percentile(data['Y_house_price_of_unit_area'], 75)
IQR = q3 - q1
lower_bound = q1 - 1.5 * IQR
upper_bound = q3 + 1.5 * IQR
sns.boxplot(data['Y_house_price_of_unit_area'])
plt.show()

# %%
# Out:
#   Cell In[29], line 1
#     filtered_data_price = data[(data['Y_house_price_of_unit_area'] >= lower_bound) & (data['Y_house_price_of_unit_area])])
#                                                                                            ^
# SyntaxError: unterminated string literal (detected at line 1)
